# %% [markdown]
# # Import des données

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("salary1.csv")
df.columns=["age","statut","f3","etudes","nombre_annees_etudes","situation_familiale1","secteur_activite","situation_familiale2","ethnie","genre", "plus-value","moins-value", "nb_h_hebdo","pays_naissance","salary"]

df
# Out:
#        age             statut      f3       etudes  nombre_annees_etudes  \
# 0       50   Self-emp-not-inc   83311    Bachelors                    13
# 1       38            Private  215646      HS-grad                     9
# 2       53            Private  234721         11th                     7
# 3       28            Private  338409    Bachelors                    13
# 4       37            Private  284582      Masters                    14
# ...    ...                ...     ...          ...                   ...
# 32555   27            Private  257302   Assoc-acdm                    12
# 32556   40            Private  154374      HS-grad                     9
# 32557   58            Private  151910      HS-grad                     9
# 32558   22            Private  201490      HS-grad                     9
# 32559   52       Self-emp-inc  287927      HS-grad                     9
#
#       situation_familiale1    secteur_activite situation_familiale2  ethnie  \
# 0       Married-civ-spouse     Exec-managerial              Husband   White
# 1                 Divorced   Handlers-cleaners        Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners              Husband   Black
# 3       Married-civ-spouse      Prof-specialty                 Wife   Black
# 4       Married-civ-spouse     Exec-managerial                 Wife   White
# ...                    ...                 ...                  ...     ...
# 32555   Married-civ-spouse        Tech-support                 Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct              Husband   White
# 32557              Widowed        Adm-clerical            Unmarried   White
# 32558        Never-married        Adm-clerical            Own-child   White
# 32559   Married-civ-spouse     Exec-managerial                 Wife   White
#
#          genre  plus-value  moins-value  nb_h_hebdo  pays_naissance  salary
# 0         Male           0            0          13   United-States   <=50K
# 1         Male           0            0          40   United-States   <=50K
# 2         Male           0            0          40   United-States   <=50K
# 3       Female           0            0          40            Cuba   <=50K
# 4       Female           0            0          40   United-States   <=50K
# ...        ...         ...          ...         ...             ...     ...
# 32555   Female           0            0          38   United-States   <=50K
# 32556     Male           0            0          40   United-States    >50K
# 32557   Female           0            0          40   United-States   <=50K
# 32558     Male           0            0          20   United-States   <=50K
# 32559   Female       15024            0          40   United-States    >50K
#
# [32560 rows x 15 columns]

# %%
#On supprime la colonne f3 qui est non informative
del df['f3']

# %%
df
# Out:
#        age             statut       etudes  nombre_annees_etudes  \
# 0       50   Self-emp-not-inc    Bachelors                    13
# 1       38            Private      HS-grad                     9
# 2       53            Private         11th                     7
# 3       28            Private    Bachelors                    13
# 4       37            Private      Masters                    14
# ...    ...                ...          ...                   ...
# 32555   27            Private   Assoc-acdm                    12
# 32556   40            Private      HS-grad                     9
# 32557   58            Private      HS-grad                     9
# 32558   22            Private      HS-grad                     9
# 32559   52       Self-emp-inc      HS-grad                     9
#
#       situation_familiale1    secteur_activite situation_familiale2  ethnie  \
# 0       Married-civ-spouse     Exec-managerial              Husband   White
# 1                 Divorced   Handlers-cleaners        Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners              Husband   Black
# 3       Married-civ-spouse      Prof-specialty                 Wife   Black
# 4       Married-civ-spouse     Exec-managerial                 Wife   White
# ...                    ...                 ...                  ...     ...
# 32555   Married-civ-spouse        Tech-support                 Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct              Husband   White
# 32557              Widowed        Adm-clerical            Unmarried   White
# 32558        Never-married        Adm-clerical            Own-child   White
# 32559   Married-civ-spouse     Exec-managerial                 Wife   White
#
#          genre  plus-value  moins-value  nb_h_hebdo  pays_naissance  salary
# 0         Male           0            0          13   United-States   <=50K
# 1         Male           0            0          40   United-States   <=50K
# 2         Male           0            0          40   United-States   <=50K
# 3       Female           0            0          40            Cuba   <=50K
# 4       Female           0            0          40   United-States   <=50K
# ...        ...         ...          ...         ...             ...     ...
# 32555   Female           0            0          38   United-States   <=50K
# 32556     Male           0            0          40   United-States    >50K
# 32557   Female           0            0          40   United-States   <=50K
# 32558     Male           0            0          20   United-States   <=50K
# 32559   Female       15024            0          40   United-States    >50K
#
# [32560 rows x 14 columns]

# %% [markdown]
# On observe que la classe salary est composée de 2 valeurs : salaires inférieurs à 50K et supérieurs à 50K.

# %%
#Avant d'effectuer une visualisation des données, on séparer notre base en appretissage/test

from sklearn.model_selection import train_test_split

#On récupère nos X et nos y
X = df.iloc[:,1:13]
y = df.iloc[:,13:14]

#On sépare nos données en train et en test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

data_train_df = (X_train,y_train)

data_test_df = (X_test, y_test)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# transformation de la classe avec le labelEncoder
y_train = y_train.apply(LabelEncoder().fit_transform)
y_train
# Out:
#        salary
# 21385       0
# 19749       0
# 1216        0
# 30048       0
# 23077       1
# ...       ...
# 29802       1
# 5390        0
# 860         0
# 15795       0
# 23654       0
#
# [22792 rows x 1 columns]

# %% [markdown]
# On applique le one-hot encoding sur les variables qualitatives nominales de manière à les transformer en variables quantitatives.

# %%
X_train = pd.concat([X_train, pd.get_dummies(X_train['statut'], prefix='statut')], axis=1)

# %%
X_train = pd.concat([X_train, pd.get_dummies(X_train['situation_familiale1'], prefix='sf1')], axis=1)

# %%
X_train = pd.concat([X_train, pd.get_dummies(X_train['secteur_activite'], prefix='se')], axis=1)

# %%
X_train = pd.concat([X_train, pd.get_dummies(X_train['situation_familiale2'], prefix='sf2')], axis=1)

# %%
X_train = pd.concat([X_train, pd.get_dummies(X_train['ethnie'], prefix='et')], axis=1)

# %%
X_train = pd.concat([X_train, pd.get_dummies(X_train['genre'], prefix='s')], axis=1)

# %%
X_train = pd.concat([X_train, pd.get_dummies(X_train['pays_naissance'], prefix='pn')], axis=1)

# %%
X_train
# Out:
#              statut      etudes  nombre_annees_etudes situation_familiale1  \
# 21385       Private   Bachelors                    13        Never-married
# 19749       Private     HS-grad                     9        Never-married
# 1216              ?     HS-grad                     9             Divorced
# 30048   Federal-gov     Masters                    14             Divorced
# 23077       Private   Doctorate                    16   Married-civ-spouse
# ...             ...         ...                   ...                  ...
# 29802       Private   Bachelors                    13        Never-married
# 5390        Private     HS-grad                     9   Married-civ-spouse
# 860         Private     HS-grad                     9   Married-civ-spouse
# 15795       Private     HS-grad                     9        Never-married
# 23654     Local-gov   Bachelors                    13             Divorced
#
#          secteur_activite situation_familiale2               ethnie    genre  \
# 21385     Exec-managerial        Not-in-family                White     Male
# 19749        Craft-repair            Own-child   Asian-Pac-Islander     Male
# 1216                    ?        Not-in-family   Asian-Pac-Islander   Female
# 30048        Adm-clerical            Unmarried                White   Female
# 23077      Prof-specialty              Husband                White     Male
# ...                   ...                  ...                  ...      ...
# 29802               Sales        Not-in-family                White   Female
# 5390    Machine-op-inspct                 Wife                White   Female
# 860       Farming-fishing              Husband                White     Male
# 15795       Other-service        Not-in-family                White   Female
# 23654      Prof-specialty       Other-relative                White   Female
#
#        plus-value  moins-value  ...  pn_ Portugal pn_ Puerto-Rico  \
# 21385           0            0  ...             0               0
# 19749           0            0  ...             0               0
# 1216            0            0  ...             0               0
# 30048           0            0  ...             0               0
# 23077       15024            0  ...             0               0
# ...           ...          ...  ...           ...             ...
# 29802        8614            0  ...             0               0
# 5390            0            0  ...             0               0
# 860             0            0  ...             0               0
# 15795        1055            0  ...             0               0
# 23654           0            0  ...             0               0
#
#        pn_ Scotland  pn_ South  pn_ Taiwan  pn_ Thailand  pn_ Trinadad&Tobago  \
# 21385             0          0           0             0                    0
# 19749             0          0           0             0                    0
# 1216              0          0           0             0                    0
# 30048             0          0           0             0                    0
# 23077             0          0           0             0                    0
# ...             ...        ...         ...           ...                  ...
# 29802             0          0           0             0                    0
# 5390              0          0           0             0                    0
# 860               0          0           0             0                    0
# 15795             0          0           0             0                    0
# 23654             0          0           0             0                    0
#
#        pn_ United-States  pn_ Vietnam  pn_ Yugoslavia
# 21385                  1            0               0
# 19749                  0            1               0
# 1216                   0            0               0
# 30048                  1            0               0
# 23077                  1            0               0
# ...                  ...          ...             ...
# 29802                  1            0               0
# 5390                   1            0               0
# 860                    0            0               0
# 15795                  1            0               0
# 23654                  1            0               0
#
# [22792 rows x 98 columns]

# %%
#On supprime nos variables qualitatives
del X_train['statut']

# %%
del X_train['nombre_annees_etudes']
del X_train['situation_familiale1']
del X_train['secteur_activite']
del X_train['situation_familiale2']
del X_train['ethnie']
del X_train['genre']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nombre_annees_etudes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-c6929b324a8f> in <module>
# ----> 1 del X_train['nombre_annees_etudes']
#       2 del X_train['situation_familiale1']
#       3 del X_train['secteur_activite']
#       4 del X_train['situation_familiale2']
#       5 del X_train['ethnie']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nombre_annees_etudes'

# %%
del X_train['pays_naissance']

# %%
X_train
# Out:
#            etudes  plus-value  moins-value  nb_h_hebdo  statut_ ?  \
# 21385   Bachelors           0            0          40          0
# 19749     HS-grad           0            0           1          0
# 1216      HS-grad           0            0          41          1
# 30048     Masters           0            0          40          0
# 23077   Doctorate       15024            0          50          0
# ...           ...         ...          ...         ...        ...
# 29802   Bachelors        8614            0          45          0
# 5390      HS-grad           0            0          55          0
# 860       HS-grad           0            0          40          0
# 15795     HS-grad        1055            0          30          0
# 23654   Bachelors           0            0          40          0
#
#        statut_ Federal-gov  statut_ Local-gov  statut_ Never-worked  \
# 21385                    0                  0                     0
# 19749                    0                  0                     0
# 1216                     0                  0                     0
# 30048                    1                  0                     0
# 23077                    0                  0                     0
# ...                    ...                ...                   ...
# 29802                    0                  0                     0
# 5390                     0                  0                     0
# 860                      0                  0                     0
# 15795                    0                  0                     0
# 23654                    0                  1                     0
#
#        statut_ Private  statut_ Self-emp-inc  ...  pn_ Portugal  \
# 21385                1                     0  ...             0
# 19749                1                     0  ...             0
# 1216                 0                     0  ...             0
# 30048                0                     0  ...             0
# 23077                1                     0  ...             0
# ...                ...                   ...  ...           ...
# 29802                1                     0  ...             0
# 5390                 1                     0  ...             0
# 860                  1                     0  ...             0
# 15795                1                     0  ...             0
# 23654                0                     0  ...             0
#
#        pn_ Puerto-Rico  pn_ Scotland  pn_ South  pn_ Taiwan  pn_ Thailand  \
# 21385                0             0          0           0             0
# 19749                0             0          0           0             0
# 1216                 0             0          0           0             0
# 30048                0             0          0           0             0
# 23077                0             0          0           0             0
# ...                ...           ...        ...         ...           ...
# 29802                0             0          0           0             0
# 5390                 0             0          0           0             0
# 860                  0             0          0           0             0
# 15795                0             0          0           0             0
# 23654                0             0          0           0             0
#
#        pn_ Trinadad&Tobago  pn_ United-States  pn_ Vietnam  pn_ Yugoslavia
# 21385                    0                  1            0               0
# 19749                    0                  0            1               0
# 1216                     0                  0            0               0
# 30048                    0                  1            0               0
# 23077                    0                  1            0               0
# ...                    ...                ...          ...             ...
# 29802                    0                  1            0               0
# 5390                     0                  1            0               0
# 860                      0                  0            0               0
# 15795                    0                  1            0               0
# 23654                    0                  1            0               0
#
# [22792 rows x 90 columns]

# %% [markdown]
# On applique l'OrdinalEncoder de manière à transformer la variable études qui est une qualitative ordinale en variable quantitative.

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
enc.fit(X_train[["etudes"]])
X_train[["etudes"]] = enc.transform(X_train[["etudes"]])

# %%
X_train
# Out:
#        etudes  plus-value  moins-value  nb_h_hebdo  statut_ ?  \
# 21385     9.0           0            0          40          0
# 19749    11.0           0            0           1          0
# 1216     11.0           0            0          41          1
# 30048    12.0           0            0          40          0
# 23077    10.0       15024            0          50          0
# ...       ...         ...          ...         ...        ...
# 29802     9.0        8614            0          45          0
# 5390     11.0           0            0          55          0
# 860      11.0           0            0          40          0
# 15795    11.0        1055            0          30          0
# 23654     9.0           0            0          40          0
#
#        statut_ Federal-gov  statut_ Local-gov  statut_ Never-worked  \
# 21385                    0                  0                     0
# 19749                    0                  0                     0
# 1216                     0                  0                     0
# 30048                    1                  0                     0
# 23077                    0                  0                     0
# ...                    ...                ...                   ...
# 29802                    0                  0                     0
# 5390                     0                  0                     0
# 860                      0                  0                     0
# 15795                    0                  0                     0
# 23654                    0                  1                     0
#
#        statut_ Private  statut_ Self-emp-inc  ...  pn_ Portugal  \
# 21385                1                     0  ...             0
# 19749                1                     0  ...             0
# 1216                 0                     0  ...             0
# 30048                0                     0  ...             0
# 23077                1                     0  ...             0
# ...                ...                   ...  ...           ...
# 29802                1                     0  ...             0
# 5390                 1                     0  ...             0
# 860                  1                     0  ...             0
# 15795                1                     0  ...             0
# 23654                0                     0  ...             0
#
#        pn_ Puerto-Rico  pn_ Scotland  pn_ South  pn_ Taiwan  pn_ Thailand  \
# 21385                0             0          0           0             0
# 19749                0             0          0           0             0
# 1216                 0             0          0           0             0
# 30048                0             0          0           0             0
# 23077                0             0          0           0             0
# ...                ...           ...        ...         ...           ...
# 29802                0             0          0           0             0
# 5390                 0             0          0           0             0
# 860                  0             0          0           0             0
# 15795                0             0          0           0             0
# 23654                0             0          0           0             0
#
#        pn_ Trinadad&Tobago  pn_ United-States  pn_ Vietnam  pn_ Yugoslavia
# 21385                    0                  1            0               0
# 19749                    0                  0            1               0
# 1216                     0                  0            0               0
# 30048                    0                  1            0               0
# 23077                    0                  1            0               0
# ...                    ...                ...          ...             ...
# 29802                    0                  1            0               0
# 5390                     0                  1            0               0
# 860                      0                  0            0               0
# 15795                    0                  1            0               0
# 23654                    0                  1            0               0
#
# [22792 rows x 90 columns]
